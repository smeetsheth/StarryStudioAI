# %%
# !pip install google-cloud-aiplatform google-cloud-storage google-auth google-auth-oauthlib jsonlines
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.70.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (2.27.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.19.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (24.1)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.13.0)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.0.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.9.2)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (24.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.65.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage) (1.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2024.8.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: numpy<3,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %%
import os
import time
import vertexai
from vertexai.preview.tuning import sft
from google.colab import drive
from google.cloud import storage
from google.cloud import aiplatform
from google.oauth2 import service_account
from vertexai.generative_models import GenerativeModel

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Defining Service Account, Input Data, Output/Training Data Paths

# %%
# Define paths
service_account_key_path = '' # Path to service account key
input_json_path = ''    # Path to input json file
jsonl_output_path = '' # Path to output jsonl file

# %%
# Set the environment variable for service account credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = service_account_key_path

# %% [markdown]
# #### Define Project ID, Region, and GCS Bucket URI

# %%
# Define Project ID, Region, and GCS Bucket URI
PROJECT_ID = ""  # Replace with your Google Cloud Project ID
REGION = "us-central1"  # Desired region for Vertex AI
BUCKET_NAME = f"{PROJECT_ID}-sft-gemini-demo"                                                                                                                                 mm
BUCKET_URI = f"gs://{BUCKET_NAME}"

# %%
# Initialize Vertex AI with credentials from environment variable
vertexai.init(project=PROJECT_ID, location=REGION)

# %% [markdown]
# ####  Converting and preparing Training data

# %%
# Prepare JSONL data if not already done
def prepare_code_generation_jsonl(input_json_path, output_jsonl_path, limit=50):
    import json
    import jsonlines

    with open(input_json_path, 'r') as f:
        original_data = json.load(f)

    with jsonlines.open(output_jsonl_path, 'w') as writer:
        for i, example in enumerate(original_data):
            if i >= limit:
                break
            formatted_example = {
                "messages": [
                    {"role": "user", "content": example["instruction"]},
                    {"role": "model", "content": example["output"]}
                ]
            }
            writer.write(formatted_example)

prepare_code_generation_jsonl(input_json_path, jsonl_output_path, limit=263)

# %% [markdown]
# #### Initializing and Creating bucket

# %%
# Initialize GCS client and upload the data
client = storage.Client(project=PROJECT_ID)
bucket = client.bucket(BUCKET_NAME)

# Create bucket if it does not exist
if not bucket.exists():
    bucket.create(location=REGION)
    print(f"Bucket created: {BUCKET_URI}")

# %%
# Define GCS paths for the data file
local_file_path = jsonl_output_path
gcs_blob_path = 'fine_tune_data_gemini.jsonl'
blob = bucket.blob(gcs_blob_path)
blob.upload_from_filename(local_file_path)
print(f"File uploaded to gs://{BUCKET_NAME}/{gcs_blob_path}")
# Out:
# File uploaded to gs://sonorous-pact-405102-sft-gemini-demo/fine_tune_data_gemini.jsonl

# %% [markdown]
# #### Defining model and Fine Tuning Job

# %%
# Define the model ID and training dataset URI
MODEL_ID = "gemini-1.0-pro-002"
TRAINING_DATA_URI = f"gs://{BUCKET_NAME}/{gcs_blob_path}"

# Start the fine-tuning job
sft_tuning_job = sft.train(
    source_model=MODEL_ID,
    train_dataset=TRAINING_DATA_URI
)

# Monitor tuning job progress
while not sft_tuning_job.has_ended:
    time.sleep(60)
    sft_tuning_job.refresh()
    print("Tuning job in progress...")

# Display tuning job information after completion
print("Tuning job completed.")
print("Tuning Job Info:", sft_tuning_job.to_dict())
print(f"Tuned Model name: {sft_tuning_job.tuned_model_name}")
print(f"Endpoint name: {sft_tuning_job.tuned_model_endpoint_name}")
# Out:
# INFO:vertexai.tuning._tuning:Creating SupervisedTuningJob
# INFO:vertexai.tuning._tuning:SupervisedTuningJob created. Resource name: projects/311149115011/locations/us-central1/tuningJobs/8249116052160512000
# INFO:vertexai.tuning._tuning:To use this SupervisedTuningJob in another session:
# INFO:vertexai.tuning._tuning:tuning_job = sft.SupervisedTuningJob('projects/311149115011/locations/us-central1/tuningJobs/8249116052160512000')
# INFO:vertexai.tuning._tuning:View Tuning Job:
# https://console.cloud.google.com/vertex-ai/generative/language/locations/us-central1/tuning/tuningJob/8249116052160512000?project=311149115011
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-2101faaa-4fea-4feb-904b-b3d67687b00b" href="#view-view-vertex-resource-2101faaa-4fea-4feb-904b-b3d67687b00b">
#           <span class="material-icons view-vertex-icon">tune</span>
#           <span>View Tuning Job</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-2101faaa-4fea-4feb-904b-b3d67687b00b');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-central1/tuning/tuningJob/8249116052160512000?project=311149115011');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-central1/tuning/tuningJob/8249116052160512000?project=311149115011', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-d3f46971-c43b-4e84-a1f0-7f3dd1c6458c" href="#view-view-vertex-resource-d3f46971-c43b-4e84-a1f0-7f3dd1c6458c">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-d3f46971-c43b-4e84-a1f0-7f3dd1c6458c');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/tuning-experiment-20241110214939389086/runs?project=sonorous-pact-405102');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/tuning-experiment-20241110214939389086/runs?project=sonorous-pact-405102', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job in progress...
# Tuning job completed.
# Tuning Job Info: {'name': 'projects/311149115011/locations/us-central1/tuningJobs/8249116052160512000', 'tunedModelDisplayName': 'SupervisedTuningJob 2024-11-11 05:35:32.161518', 'baseModel': 'gemini-1.0-pro-002', 'supervisedTuningSpec': {'trainingDatasetUri': 'gs://sonorous-pact-405102-sft-gemini-demo/fine_tune_data_gemini.jsonl', 'hyperParameters': {'epochCount': '4', 'learningRateMultiplier': 1.0, 'adapterSize': 'ADAPTER_SIZE_ONE'}}, 'state': 'JOB_STATE_SUCCEEDED', 'createTime': '2024-11-11T05:35:32.685575Z', 'startTime': '2024-11-11T05:35:32.720561Z', 'endTime': '2024-11-11T06:51:26.418092Z', 'updateTime': '2024-11-11T06:51:26.418092Z', 'experiment': 'projects/311149115011/locations/us-central1/metadataStores/default/contexts/tuning-experiment-20241110214939389086', 'tunedModel': {'model': 'projects/311149115011/locations/us-central1/models/827154900994490368@1', 'endpoint': 'projects/311149115011/locations/us-central1/endpoints/7869109062481215488'}, 'tuningDataStats': {'supervisedTuningDataStats': {'tuningDatasetExampleCount': '263', 'totalTuningCharacterCount': '1831710', 'tuningStepCount': '132', 'userInputTokenDistribution': {'sum': '22115', 'min': 67.0, 'max': 127.0, 'mean': 84.08745247148289, 'median': 83.0, 'p5': 73.0, 'p95': 102.0, 'buckets': [{'count': 47.0, 'left': 67.0, 'right': 77.0}, {'count': 163.0, 'left': 78.0, 'right': 87.0}, {'count': 37.0, 'left': 88.0, 'right': 97.0}, {'count': 7.0, 'left': 98.0, 'right': 107.0}, {'count': 7.0, 'left': 108.0, 'right': 117.0}, {'count': 2.0, 'left': 118.0, 'right': 127.0}], 'billableSum': '22115'}, 'userOutputTokenDistribution': {'sum': '707812', 'min': 229.0, 'max': 21824.0, 'mean': 2691.300380228137, 'median': 2129.0, 'p5': 753.0, 'p95': 6100.0, 'buckets': [{'count': 215.0, 'left': 207.0, 'right': 3828.0}, {'count': 44.0, 'left': 3829.0, 'right': 7427.0}, {'count': 2.0, 'left': 7428.0, 'right': 11026.0}, {'count': 2.0, 'left': 18226.0, 'right': 21824.0}], 'billableSum': '707812'}, 'userMessagePerExampleDistribution': {'sum': '526', 'min': 2.0, 'max': 2.0, 'mean': 2.0, 'median': 2.0, 'p5': 2.0, 'p95': 2.0, 'buckets': [{'count': 263.0, 'left': 2.0, 'right': 2.0}], 'billableSum': '526'}, 'userDatasetExamples': [{'role': 'user', 'parts': [{'text': 'Create a header of a personal portfolio website with a modern, clean aesthetic. Utilize HTML for logo, navigation bar, and concise intro sections, each with distinct calls-to-action. Employ CSS to emphasize typography, color contrasts, and hover interactions, focusing on readability and intuitive layout for seamless navigation while aligning with UI/UX best practices.'}]}, {'role': 'model', 'parts': [{'text': '<html>\n<head>\n<style>\n.icon {\n  \tposition: absolute;\n  \ttop: 42px;\n  \tleft: 0px;\n  \twidth: 36.4px;\n  \theight: 34px;\n  \toverflow: hidden;\n}\n.devstack {\n  \tcolor: #3f3a64;\n}\n.v-devstack {\n  \tposition: absolute;\n  \ttop: 0px;\n  \tleft: 36.44px;\n  \tline-height: 51px;\n  \ttext-transform: capitalize;\n}\n.link {\n  \tposition: absolute;\n  \ttop: calc(50% - 25.51px);\n  \tleft: 0px;\n  \twidth: 221.9px;...'}]}, {'role': 'user', 'parts': [{'text': 'Create a header of a Photography Portfolio Website, focused on showcasing minimalistic and elegant visuals. Integrate HTML components for smooth navigation, header images, and call to action buttons. Use CSS for image overlays, typography accents, spacing, and hover effects. Prioritize visual storytelling, contrast, clean aesthetics, and alignment to create an immersive experience that follows...'}]}, {'role': 'model', 'parts': [{'text': '<html>\n<head>\n<style>\n.bg {\n  \tposition: absolute;\n  \ttop: 0px;\n  \tleft: 329px;\n  \tbackground-color: #dfe3eb;\n  \twidth: 724px;\n  \theight: 1080px;\n  \topacity: 0.6;\n}\n.image-icon {\n  \tposition: absolute;\n  \ttop: 106px;\n  \tleft: 0px;\n  \twidth: 870px;\n  \theight: 974px;\n  \tobject-fit: cover;\n}\n.dot-icon {\n  \tposition: absolute;\n  \ttop: 417px;\n  \tleft: 660px;\n  \twidth: 68px;\n  \theight:  ...
# Tuned Model name: projects/311149115011/locations/us-central1/models/827154900994490368@1
# Endpoint name: projects/311149115011/locations/us-central1/endpoints/7869109062481215488

# %% [markdown]
# #### Generating outputs

# %%
# Define the full model path based on the tuning job info
MODEL_NAME = "" # Define model Endpoint name here

# Load the fine-tuned model
model = GenerativeModel(model_name=MODEL_NAME)

# Test with a prompt similar to your training data
try:
    # Sample prompts from your training data
    prompts = [
      "Create a header for a minimalist personal website, focusing on clean typography and a simple navigation bar.",
      "Design a bold and striking header for a creative agency website, incorporating a strong visual element and a prominent call-to-action.",
      "Develop a functional and user-friendly header for an e-commerce website, including a logo, search bar, shopping cart icon, and clear navigation.",
      "Create a visually appealing header for a blog website, featuring a large hero image, a tagline, and a simple navigation bar.",
      ]

    # Send each prompt to the model and print the generated responses
    for prompt in prompts:
        response = model.generate_content(prompt)
        print(f"Prompt: {prompt}\nGenerated Response:\n{response.text}\n")
        print("-" * 50)

except Exception as e:
    print("Error generating response:", e)
# Out:
# Prompt: Create a header for a minimalist personal website, focusing on clean typography and a simple navigation bar.
# Generated Response:
# <html>
# <head>
# <style>
# .section-1 {
#   	width: 100%;
#   	background: #ffffff;
#   	display: flex;
#   	flex-direction: column;
#   	align-items: center;
#   	justify-content: center;
#   	padding: 10px;
#   	position: relative;
#   	z-index: 0;
# }
# .link {
#   	font-size: 20px;
#   	color: #000000;
# }
# .nav-link {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 32px;
# }
# .nav-container {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 24px;
# }
# .container {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: flex-start;
#   	justify-content: flex-start;
#   	gap: 56px;
# }
# .div {
#   	position: absolute;
#   	top: calc(50% - 39.5px);
#   	left: calc(50% - 167px);
#   	width: 374px;
#   	height: 89px;
#   	background-image: url(Ellipse.png);
#   	background-size: 100%;
#   	background-position: 50%;
#   	background-repeat: no-repeat;
#   	z-index: 1;
# }
# .nav-parent {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: flex-start;
#   	justify-content: flex-start;
#   	gap: 8px;
#   	position: absolute;
#   	top: 176px;
#   	left: 96px;
# }
# .div1 {
#   	position: absolute;
#   	top: calc(50% - 46.5px);
#   	left: calc(50% - 185px);
#   	width: 374px;
#   	height: 93px;
#   	background-image: url(Ellipse.png);
#   	background-size: 100%;
#   	background-position: 50%;
#   	background-repeat: no-repeat;
#   	z-index: 1;
# }
# .nav-parent1 {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: flex-start;
#   	justify-content: flex-start;
#   	gap: 8px;
#   	position: absolute;
#   	top: 393px;
#   	left: 96px;
# }
# .div2 {
#   	position: absolute;
#   	top: calc(50% - 47.5px);
#   	left: calc(50% - 193px);
#   	width: 374px;
#   	height: 95px;
#   	background-image: url(Ellipse.png);
#   	background-size: 100%;
#   	background-position: 50%;
#   	background-repeat: no-repeat;
#   	z-index: 1;
# }
# .nav-parent2 {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: flex-start;
#   	justify-content: flex-start;
#   	gap: 8px;
#   	position: absolute;
#   	top: 609px;
#   	left: 96px;
# }
# .icon {
#   	width: 16px;
#   	height: 16px;
# }
# .img-group {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
# }
# .nav-bar {
#   	display: flex;
#   	flex-direction: column;
#   	align-items: flex-start;
#   	justify-content: flex-start;
#   	padding: 0px;
#   	position: absolute;
#   	top: 176px;
#   	left: 79px;
#   	z-index: 2;
# }
# .home {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 12px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 20px;
#   	color: #0f0e0e;
# }
# .about {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 12px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 20px;
#   	color: #000000;
# }
# .works {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 12px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 20px;
#   	color: #000000;
# }
# .contact {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 12px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 20px;
#   	color: #000000;
# }
# .nav-item {
#   	width: 108px;
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: flex-start;
#   	gap: 24px;
# }
# .icon1 {
#   	width: 20px;
#   	height: 20px;
# }
# .logo {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	gap: 12px;
# }
# .content-text-parent {
#   	width: 586px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 24px;
#   	color: #000000;
#   	position: absolute;
#   	top: 294px;
#   	left: 775px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .div3 {
#   	width: 586px;
#   	font-family: 'Poppins';
#   	font-weight: 400;
#   	font-size: 18px;
#   	color: #000000;
#   	position: absolute;
#   	top: 373px;
#   	left: 775px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .i-am-a-content-writer-designer {
#   	width: 589px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 48px;
#   	color: #000000;
#   	position: absolute;
#   	top: 167px;
#   	left: 775px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: pre-wrap;
#   	display: block;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .text {
#   	display: flex;
#   	flex-direction: column;
#   	align-items: flex-start;
#   	justify-content: flex-start;
#   	gap: 16px;
#   	position: absolute;
#   	top: 164px;
#   	left: 775px;
# }
# .button {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	padding: 12px 40px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 18px;
#   	color: #fff;
#   	background: #f39186;
#   	position: absolute;
#   	top: 526px;
#   	left: 775px;
#   	border-radius: 30px;
#   	box-shadow: 0px 4px 20px 2px rgba(243, 145, 134, 0.2);
# }
# .footer {
#   	position: absolute;
#   	top: 1117px;
#   	left: 431px;
#   	width: 100%;
#   	height: 452px;
# }
# .img {
#   	position: absolute;
#   	top: 128px;
#   	left: 0px;
#   	width: 100%;
#   	height: 690px;
#   	object-fit: cover;
# }
# .hero {
#   	position: absolute;
#   	top: 0px;
#   	left: 61px;
#   	width: 1049px;
#   	height: 757px;
#   	background-color: #ffffff;
#   	overflow: hidden;
# }
# .button1 {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	padding: 12px 40px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 18px;
#   	color: #fff;
#   	background: #f39186;
#   	position: absolute;
#   	top: 565px;
#   	left: 775px;
#   	border-radius: 30px;
#   	box-shadow: 0px 4px 20px 2px rgba(243, 145, 134, 0.2);
# }
# .content {
#   	position: absolute;
#   	top: 1025px;
#   	left: 431px;
#   	width: 100%;
#   	height: 878px;
# }
# .div4 {
#   	position: absolute;
#   	top: 1366px;
#   	left: 0px;
#   	width: 100%;
#   	height: 296px;
#   	background-color: #ffffff;
#   	overflow: hidden;
# }
# .div5 {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 536px;
#   	height: 296px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 48px;
#   	color: #000000;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .div6 {
#   	width: 586px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 24px;
#   	color: #0f0e0e;
#   	position: absolute;
#   	top: 38px;
#   	left: 596px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .div7 {
#   	width: 586px;
#   	font-family: 'Poppins';
#   	font-weight: 400;
#   	font-size: 18px;
#   	color: #000000;
#   	position: absolute;
#   	top: 127px;
#   	left: 596px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .div8 {
#   	width: 586px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 24px;
#   	color: #0f0e0e;
#   	position: absolute;
#   	top: 260px;
#   	left: 596px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .div9 {
#   	width: 586px;
#   	font-family: 'Poppins';
#   	font-weight: 400;
#   	font-size: 18px;
#   	color: #000000;
#   	position: absolute;
#   	top: 349px;
#   	left: 596px;
#   	overflow: hidden;
#   	text-overflow: ellipsis;
#   	white-space: nowrap;
#   	display: -webkit-box;
#   	-webkit-line-clamp: 2;
#   	-webkit-box-orient: vertical;
# }
# .content-text {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 1199px;
#   	height: 296px;
# }
# .button2 {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	padding: 12px 40px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 18px;
#   	color: #fff;
#   	background: #f39186;
#   	position: absolute;
#   	top: 565px;
#   	left: 596px;
#   	border-radius: 30px;
#   	box-shadow: 0px 4px 20px 2px rgba(243, 145, 134, 0.2);
# }
# .button3 {
#   	display: flex;
#   	flex-direction: row;
#   	align-items: center;
#   	justify-content: center;
#   	padding: 12px 40px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 18px;
#   	color: #fff;
#   	background: #f39186;
#   	position: absolute;
#   	top: 565px;
#   	left: 775px;
#   	border-radius: 30px;
#   	box-shadow: 0px 4px 20px 2px rgba(243, 145, 134, 0.2);
# }
# .footer1 {
#   	position: absolute;
#   	top: 1909px;
#   	left: 431px;
#   	width: 100%;
#   	height: 452px;
# }
# .div10 {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 156px;
#   	height: 241px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div11 {
#   	position: absolute;
#   	top: 226px;
#   	left: 0px;
#   	width: 100%;
#   	height: 240px;
# }
# .div12 {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 100%;
#   	height: 114px;
#   	background: #f39186;
# }
# .div13 {
#   	position: absolute;
#   	top: 27px;
#   	left: 29px;
#   	width: 264px;
#   	height: 30px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 16px;
#   	color: #fff;
# }
# .div14 {
#   	position: absolute;
#   	top: 79px;
#   	left: 29px;
#   	width: 199px;
#   	height: 21px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .logo1 {
#   	position: absolute;
#   	top: 207px;
#   	left: 70px;
#   	width: 176px;
#   	height: 34px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 24px;
#   	color: #fff;
# }
# .div15 {
#   	position: absolute;
#   	top: 98px;
#   	left: 187px;
#   	width: 157px;
#   	height: 21px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div16 {
#   	position: absolute;
#   	top: 98px;
#   	left: 187px;
#   	width: 157px;
#   	height: 21px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div17 {
#   	position: absolute;
#   	top: 98px;
#   	left: 187px;
#   	width: 157px;
#   	height: 21px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div18 {
#   	position: absolute;
#   	top: 98px;
#   	left: 187px;
#   	width: 157px;
#   	height: 21px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div19 {
#   	position: absolute;
#   	top: 196px;
#   	left: 29px;
#   	width: 110px;
#   	height: 27px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 18px;
#   	color: #fff;
# }
# .div20 {
#   	width: 394px;
#   	position: absolute;
#   	top: 65px;
#   	left: 29px;
#   	height: 131px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .footer2 {
#   	position: absolute;
#   	top: 0px;
#   	left: 685px;
#   	width: 347px;
#   	height: 481px;
# }
# .footer3 {
#   	position: absolute;
#   	top: 0px;
#   	left: 99px;
#   	width: 575px;
#   	height: 481px;
# }
# .footer4 {
#   	position: absolute;
#   	top: 64px;
#   	left: 516px;
#   	width: 359px;
#   	height: 417px;
# }
# .footer5 {
#   	position: absolute;
#   	top: 2681px;
#   	left: 0px;
#   	width: 100%;
#   	height: 481px;
# }
# .rectangle {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 100%;
#   	height: 481px;
#   	background: #f39186;
#   	box-shadow: 0px 4px 20px 2px rgba(243, 145, 134, 0.2);
# }
# .section-2 {
#   	width: 100%;
#   	height: 481px;
#   	background: #fff;
#   	text-align: left;
#   	font-size: 14px;
#   	color: #000;
#   	font-family: 'Poppins';
# }
# .section-3 {
#   	width: 100%;
#   	background: #000;
#   	text-align: center;
#   	display: flex;
#   	flex-direction: column;
#   	align-items: center;
#   	justify-content: center;
#   	padding: 0px;
#   	font-size: 14px;
#   	color: #fff;
#   	font-family: 'Poppins';
# }
# .section-4 {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 100%;
#   	height: 2367px;
#   	background-color: #fff;
# }
# .div21 {
#   	position: absolute;
#   	top: 91px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div22 {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 100%;
#   	height: 117px;
#   	background: #f39186;
# }
# .div23 {
#   	position: absolute;
#   	top: 28px;
#   	left: 24px;
#   	width: 261px;
#   	height: 32px;
#   	font-family: 'Poppins';
#   	font-weight: 500;
#   	font-size: 22px;
#   	color: #fff;
# }
# .div24 {
#   	position: absolute;
#   	top: 76px;
#   	left: 24px;
#   	width: 277px;
#   	height: 33px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 22px;
#   	color: #fff;
# }
# .div25 {
#   	width: 309px;
#   	position: absolute;
#   	top: 59px;
#   	left: 1069px;
#   	height: 85px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div26 {
#   	position: absolute;
#   	top: 251px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div27 {
#   	position: absolute;
#   	top: 504px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div28 {
#   	position: absolute;
#   	top: 757px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div29 {
#   	position: absolute;
#   	top: 1009px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div30 {
#   	position: absolute;
#   	top: 1262px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div31 {
#   	position: absolute;
#   	top: 1515px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div32 {
#   	position: absolute;
#   	top: 1768px;
#   	left: 0px;
#   	width: 303px;
#   	height: 211px;
#   	overflow: hidden;
#   	object-fit: cover;
# }
# .div33 {
#   	width: 309px;
#   	position: absolute;
#   	top: 167px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div34 {
#   	width: 309px;
#   	position: absolute;
#   	top: 396px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div35 {
#   	width: 309px;
#   	position: absolute;
#   	top: 649px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div36 {
#   	width: 309px;
#   	position: absolute;
#   	top: 902px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div37 {
#   	width: 309px;
#   	position: absolute;
#   	top: 1155px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div38 {
#   	width: 309px;
#   	position: absolute;
#   	top: 1408px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .div39 {
#   	width: 309px;
#   	position: absolute;
#   	top: 1661px;
#   	left: 381px;
#   	height: 129px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 14px;
#   	color: #fff;
# }
# .section-5 {
#   	width: 100%;
#   	height: 1786px;
#   	background: #fff;
#   	text-align: left;
#   	font-size: 14px;
#   	color: #000;
#   	font-family: 'Poppins';
# }
# .rectangle1 {
#   	position: absolute;
#   	top: 0px;
#   	left: 698px;
#   	width: 291px;
#   	height: 37px;
#   	background: #fff;
# }
# .rectangle2 {
#   	position: absolute;
#   	top: 0px;
#   	left: 0px;
#   	width: 698px;
#   	height: 37px;
#   	background: #000;
# }
# .div40 {
#   	position: absolute;
#   	top: 7px;
#   	left: 174px;
#   	width: 463px;
#   	height: 32px;
#   	font-family: 'Poppins';
#   	font-weight: 600;
#   	font-size: 22px;
#   	color: #000;
# }
# .section-6 {
#   	width: 100%;
#   	position: relative;
#   	height: 37px;
#   	background: #000;
#   	text-align: left;
#   	font-size: 14px;
#   	color: #fff;
#   	font-family: 'Poppins';
# }
# body {
#   	margin: 0;
#   	line-height: normal;
# }
# </style>
# </head>
# <body>
# <!DOCTYPE html>
# <html>
# <head>
#   	<meta charset="utf-8">
#   	<meta name="viewport" content="initial-scale=1, width=device-width">
#
#   	<link rel="stylesheet"  href="./index.css" />
#   	<link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Poppins:wght@400;500;600;700&display=swap" />
#
#
#
# </head>
# <body>
#
#   	<div class="section-1">
#     		<div class="container">
#       			<div class="nav-container">
#         				<div class="nav-parent">
#           					<div class="nav-link">
#             						<div class="home">Home</div>
#             						<div class="about">About</div>
#             						<div class="works">Works</div>
#             						<div class="contact">Contact</div>
#           					</div>
#           					<div class="img">
#             						<img class="icon" alt="" src="Ellipse.png">
#
#           					</div
#
# --------------------------------------------------
# Prompt: Design a bold and striking header for a creative agency website, incorporating a strong visual element and a prominent call-to-action.
# Generated Response:
# ## Header Design: Creative Agency
#
# **Visual element:** A dynamic, vibrant illustration of a brain with colorful paint splatters, symbolizing the agency's creative and innovative spirit.
#
# **Call-to-action:** "Let's create something amazing!"
#
# **Style:** Bold, modern, and playful.
#
# **Colors:** Bright and energetic, with a strong color contrast.
#
# **Font:** A chunky, sans-serif font for the tagline and a cleaner, sans-serif font for the call-to-action.
#
# **Note:** This is just a description. You can create this banner by using a graphic design tool such as Canva or Adobe Photoshop.
#
# **Example banner:**
#
# [![Example Creative Agency Banner](https://i.imgur.com/J9s953n.png)](https://i.imgur.com/J9s953n.png)
#
# **Additional details:**
#
# * The brain illustration should have a 3D effect for a more dynamic look.
# * Add some small, detailed elements like gears and arrows to represent the agency's process and solutions.
# * Use a different color for the call-to-action button to make it stand out.
# * You can adjust the size and position of the elements to achieve the desired balance.
#
# **Benefits of this design:**
#
# * **Eye-catching and memorable:** The vibrant colors and dynamic illustration will attract attention and create a lasting impression.
# * **Bold and confident:** The strong visuals and clear message convey the agency's confidence and expertise.
# * **Playful and engaging:** The overall style of the banner is playful and engaging, making it more appealing to the target audience.
# * **Versatility:** You can easily adapt this design to different sizes and formats without losing its impact.
#
# This is just one example, you can explore different styles and customize the design to fit your specific needs and brand identity.
#
# --------------------------------------------------
# Prompt: Develop a functional and user-friendly header for an e-commerce website, including a logo, search bar, shopping cart icon, and clear navigation.
# Generated Response:
# ## E-commerce Website Header
#
# ```html
# <header>
#   <div class="container">
#     <div class="logo">
#       <img src="logo.png" alt="Logo">
#     </div>
#     <div class="search-bar">
#       <input type="text" placeholder="Search for products..." />
#     </div>
#     <div class="navigation">
#       <ul>
#         <li>Home</li>
#         <li>About</li>
#         <li>Products</li>
#         <li>Contact</li>
#       </ul>
#     </div>
#     <div class="cart">
#       <i class="fa fa-shopping-cart"></i>
#       <div class="cart-icon">
#         <span class="counter">0</span>
#       </div>
#     </div>
#     <div class="account">
#       <i class="fa fa-user"></i>
#     </div>
#   </div>
# </header>
# ```
#
# This code creates a header for an e-commerce website. The header has a container which includes a logo, search bar, navigation, cart icon, and user account icon.
#
# **Features:**
#
# * Responsive design that works across different screen sizes.
# * Easy to update the logo, search bar and menu items.
# * Customizable cart icon and user account icon.
# * CSS styles can be added to modify the appearance of the header.
#
# **Additional functionalities:**
#
# * Search bar with autocomplete suggestions
# * Ability to add items to the cart directly from the search bar
# * Wishlist and compare features
# * User login and account management
# * Multiple language support
#
# **Note:**
#
# * The code uses Font Awesome icons for the cart and user icons. You need to include the Font Awesome library in your project.
# * The cart counter is set to 0 initially. You can update the counter dynamically based on the number of items in the cart.
# * This is a basic header for an e-commerce website. You can customize the code and add more functionalities to meet your specific needs.
#
# --------------------------------------------------
# Prompt: Create a visually appealing header for a blog website, featuring a large hero image, a tagline, and a simple navigation bar.
# Generated Response:
# <html>
# <head>
# <style>
# .child-of-header {
#   	position: absolute;
#   	top: 476px;
#   	left: 306px;
#   	width: 31px;
#   	height: 31px;
#   	object-fit: cover;
# }
# .explore-icon {
#   	position: absolute;
#   	top: 434px;
#   	left: 306px;
#   	width: 111px;
#   	height: 31px;
#   	font-size: 24px;
#   	font-weight: 700;
#   	line-height: 31px;
# }
# .child-of-header1 {
#   	position: absolute;
#   	top: 494px;
#   	left: 310px;
#   	width: 31px;
#   	height: 31px;
#   	object-fit: cover;
# }
# .contact-icon {
#   	position: absolute;
#   	top: 434px;
#   	left: 500px;
#   	width: 122px;
#   	height: 31px;
#   	font-size: 24px;
#   	font-weight: 700;
#   	line-height: 31px;
# }
# .child-of-header2 {
#   	position: absolute;
#   	top: 494px;
#   	left: 504px;
#   	width: 31px;
#   	height: 31px;
#   	object-fit: cover;
# }
# .product-icon {
#   	position: absolute;
#   	top: 434px;
#   	left: 700px;
#   	width: 118px;
#   	height: 31px;
#   	font-size: 24px;
#   	font-weight: 700;
#   	line-height: 31px;
# }
# .child-of-header3 {
#   	position: absolute;
#   	top: 494px;
#   	left: 704px;
#   	width: 31px;
#   	height: 31px;
#   	object-fit: cover;
# }
# .about-icon {
#   	position: absolute;
#   	top: 434px;
#   	left: 900px;
#   	width: 112px;
#   	height: 31px;
#   	font-size: 24px;
#   	font-weight: 700;
#   	line-height: 31px;
# }
# .child-of-header4 {
#   	position: absolute;
#   	top: 494px;
#   	left: 904px;
#   	width: 31px;
#   	height: 31px;
#   	object-fit: cover;
# }
# .home-icon {
#   	position: absolute;
#   	top: 434px;
#   	left: 1086px;
#   	width: 70px;
#   	height: 31px;
#   	font-size: 24px;
#   	font-weight: 700;
#   	line-height: 31px;
# }
# .child-of-header5 {
#   	position: absolute;
#   	top: 487px;
#   	left: 1089px;
#   	width: 31px;
#   	height: 31px;
#   	object-fit: cover;
# }
# .group-icon {
#   	position: absolute;
#   	top: 476px;
#   	left: 340px;
#   	width: 184px;
#   	height: 112px;
# }
# .group-icon1 {
#   	position: absolute;
#   	top: 476px;
#   	left: 540px;
#   	width: 181px;
#   	height: 112px;
# }
# .group-icon2 {
#   	position: absolute;
#   	top: 476px;
#   	left: 740px;
#   	width: 185px;
#   	height: 112px;
# }
# .group-icon3 {
#   	position: absolute;
#   	top: 476px;
#   	left: 940px;
#   	width: 183px;
#   	height: 112px;
# }
# .group-icon4 {
#   	position: absolute;
#   	top: 476px;
#   	left: 1140px;
#   	width: 181px;
#   	height: 112px;
# }
# .navigation {
#   	position: absolute;
#   	top: 429px;
#   	left: 290px;
#   	width: 960px;
#   	height: 106px;
# }
# .header-text {
#   	position: absolute;
#   	top: 300px;
#   	left: 300px;
#   	width: 648px;
#   	height: 101px;
#   	font-size: 50px;
#   	font-weight: 700;
#   	line-height: 51px;
#   	text-align: left;
# }
# .header {
#   	position: absolute;
#   	top: 220px;
#   	left: 219px;
#   	width: 960px;
#   	height: 536px;
# }
# .hero {
#   	width: 100%;
#   	position: relative;
#   	height: 810px;
#   	background-image: url("Hero.png");
#   	background-size: cover;
#   	background-repeat: no-repeat;
# }
#
#
# body {
#   	margin: 0;
#   	line-height: normal;
# }
# </style>
# </head>
# <body>
# <!DOCTYPE html>
# <html>
# <head>
#   	<meta charset="utf-8">
#   	<meta name="viewport" content="initial-scale=1, width=device-width">
#
#   	<link rel="stylesheet"  href="./index.css" />
#   	<link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Inter:wght@400;700&display=swap" />
#
#
#
# </head>
# <body>
#
#   	<div class="hero">
#     		<div class="header">
#       			<div class="header-text">
#         				We make <br>
#         				<span>Digital Products & Services</span>
#       			</div>
#       			<div class="navigation">
#         				<img class="child-of-header" alt="" src="Group 9.png">
#
#         				<div class="explore-icon">Explore</div>
#         				<img class="child-of-header1" alt="" src="Group 9.png">
#
#         				<div class="contact-icon">Contact Us</div>
#         				<img class="child-of-header2" alt="" src="Group 9.png">
#
#         				<div class="product-icon">Products</div>
#         				<img class="child-of-header3" alt="" src="Group 9.png">
#
#         				<div class="about-icon">About</div>
#         				<img class="child-of-header4" alt="" src="Group 9.png">
#
#         				<div class="home-icon">Home</div>
#         				<img class="child-of-header5" alt="" src="Group 9.png">
#
#       			</div>
#       			<div class="group-icon">
#         				<img class="child-of-header" alt="" src="Group 9.png">
#
#         				<div class="explore-icon">Explore</div>
#       			</div>
#       			<div class="group-icon1">
#         				<img class="child-of-header" alt="" src="Group 9.png">
#
#         				<div class="explore-icon">Explore</div>
#       			</div>
#       			<div class="group-icon2">
#         				<img class="child-of-header" alt="" src="Group 9.png">
#
#         				<div class="explore-icon">Explore</div>
#       			</div>
#       			<div class="group-icon3">
#         				<img class="child-of-header" alt="" src="Group 9.png">
#
#         				<div class="explore-icon">Explore</div>
#       			</div>
#       			<div class="group-icon4">
#         				<img class="child-of-header" alt="" src="Group 9.png">
#
#         				<div class="explore-icon">Explore</div>
#       			</div>
#     		</div>
#   	</div>
#
#
#
#
# </body>
# </html>
# </body>
# </html>
#
# --------------------------------------------------
